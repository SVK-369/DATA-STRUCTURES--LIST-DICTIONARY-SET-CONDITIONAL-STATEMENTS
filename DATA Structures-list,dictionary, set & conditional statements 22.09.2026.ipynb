# %%
#1. LIST (CREATION,MODIFICATION & ACESS)
#1.LIST CREATION
#A. create age_list with five integer elements
age_list =[25, 28, 31, 32, 40]
#B.create name_list with five string elements
name_list =["chintu", "sathish", "vijay", "ashok", "badri"]
#2.list operation/modifications
#a.append "Yazhini" to name_list
name_list.append("Yazhini")
print(name_list)
#b.insert element 30 at index 2 in age_list
age_list.insert(2, 30)
print(age_list)
#c.remove "Yazhini" from name_list
name_list.remove("Yazhini")
print(name_list)
#d.pop the last element fromn age_list
age_list.pop()
print(age_list)
#e.extend age_list in with additional ages [29, 30, 26]
age_list.extend([29, 30, 26])
print(age_list)
#f.sort age_list in descending order
age_list.sort(reverse=True)
#g.max, min and sum of age_list
max_age = max(age_list)
min_age = min(age_list)
sum_age =sum(age_list)
print("Sorted age_list(descending):", age_list)
print("Max age:", max_age, "| Min age:", min_age, "| Sum of ages:", sum_age)

 #assuming name_list = ["chintu", "sathish", "vijay", "ashok", "badri"]
#A. PRINT FIRST ELEMENT
print("First element:", name_list[0])
#B. print last element
print("Last element:", name_list[0-1])
#c.print elements from  index 2 to index 4 (slice up to index 5 to include 4)
print("Elements from index 2 to 4:", name_list[2:5])
#D. print elements in reverse order 
print("Reversed list :", name_list[::-1])


#DICTIONARY (CREATION, MODIFICATIN AND ACCESS)
#a. create dictionary student_marks
student_marks = {"sarswathi": 90, "laksmi": 95, "darani": 80, "amrutha":85, "megana":60}
#b. access and print marks of a specific student 
print("laksmi's marks:", student_marks["laksmi"])
#c. add new student "janani" with marks 80
student_marks["Janani"]=80
print(student_marks)
#d. update marks of any older student to 82
student_marks["megana"]=82
print(student_marks)

#e. USE KEYS(), VALUES(), AND ITEMS METHODS
print("keys:",list(student_marks.keys())) 
print("values:", list(student_marks.values()))
print("key_value pairs:", list(student_marks.items()))


#SETS(OPERATION
#a,create my_set & analyze
my_set= {'a','e','i','o','u','a','a','i'}
print(my_set)
#b.attempting indexed assignment:
#my_set[4]= 's'
#explanation:this will raise a type error: 'set' object does not support item assignment.sets are unordered and
#unindexed collections in python, so you cannot access or modify elements using square bracket indexing([]).
my_set.add('s')
print(my_set)
#c.create two sets 
set1 ={1,3,5,7,9}
set2={2.3,5,8,10}
#d.compute and print the union and intersection of set1 and set2
union_set = set1.union(set2)
intersection_set= set1.intersection(set2)
print("union:", union_set)
print("intersection:",intersection_set)



#operators & conditional statements:(IF,ELIF & ELSE)
#1.prompt user for input 
score = float(input("enter your score (0 to 10): "))
#2, 3&4 . perfom evalution and prompt output based on score range 
if score>7 and score <=10:
    print("above average: excellent work! keep performing at this level.")
elif 4<=score <=7:
    if score==7:
        print("average: good effort! keep practicing, there's room for improvement.")
elif 0 <= score < 4:
    print("below average :need to improve your performance , cosistent practice will lead to better results.")
else:
    print("invalid score! please enter a number between 0 and 10.")
# Out:
# ['chintu', 'sathish', 'vijay', 'ashok', 'badri', 'Yazhini']
# [25, 28, 30, 31, 32, 40]
# ['chintu', 'sathish', 'vijay', 'ashok', 'badri']
# [25, 28, 30, 31, 32]
# [25, 28, 30, 31, 32, 29, 30, 26]
# Sorted age_list(descending): [32, 31, 30, 30, 29, 28, 26, 25]
# Max age: 32 | Min age: 25 | Sum of ages: 231
# First element: chintu
# Last element: badri
# Elements from index 2 to 4: ['vijay', 'ashok', 'badri']
# Reversed list : ['badri', 'ashok', 'vijay', 'sathish', 'chintu']
# laksmi's marks: 95
# {'sarswathi': 90, 'laksmi': 95, 'darani': 80, 'amrutha': 85, 'megana': 60, 'Janani': 80}
# {'sarswathi': 90, 'laksmi': 95, 'darani': 80, 'amrutha': 85, 'megana': 82, 'Janani': 80}
# keys: ['sarswathi', 'laksmi', 'darani', 'amrutha', 'megana', 'Janani']
# values: [90, 95, 80, 85, 82, 80]
# key_value pairs: [('sarswathi', 90), ('laksmi', 95), ('darani', 80), ('amrutha', 85), ('megana', 82), ('Janani', 80)]
# {'e', 'o', 'a', 'u', 'i'}
# {'e', 'o', 'a', 'u', 'i', 's'}
# ...
